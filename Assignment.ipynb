# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import cmapPy.pandasGEXpress.parse as parse
import seaborn as sns
import matplotlib.pyplot as plt
from GSVA import gsva
from sklearn.preprocessing import StandardScaler
paad = parse.parse("C:\\Users\\nisha\\Downloads\\ABC.gct")
col_meta_data = paad.col_metadata_df
df1 = paad.data_df.dropna()
df=df1.T
pca = PCA(n_components=2)
X_std = StandardScaler().fit_transform(df)
principalComponents = pca.fit_transform(X_std)
print(pca.explained_variance_ratio_)
Df = pd.DataFrame(data = principalComponents,columns=['1','2'] )
Df['histological_type_other']=col_meta_data['histological_type_other'].values
sns.lmplot(x = '1', y= '2', data = principalDf, fit_reg = False,legend = 'Full')
sns.lmplot(x = '1', y= '2', data = principalDf, fit_reg = False, hue='histological_type_other',legend = 'Full')
plt.show()
# Out:
# [0.16429956 0.11939841]
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="1096.6666666666667">

# %% [markdown]
# 1. As can be observed from the above distribution of PCA1 vs PCA2 we can see that the scatter plot of the same provides evidence that the cell genes are highly expressed for some of the observations with majority having a normal gene expression concentrated in the bottom left of the graph above.
# 2. Green colored cells are related to neuroendocrine tumors while blue and pink colored cells are related to adenocarcinoma tumors. As can be observed the two groups are very much separated and easily identifiable
# 3. Variance of PCA1 = 0.16429956 and Variance of PCA2 = 0.11939841 . This implies that PCA1 includes 16.42% of the information and PCA2 includes 11.94% of the information. Since cumulative variance from PCA1 and PCA2 is only about 28% that is while projecting high dimensional data to a two dimensional data, 72% information was lost.

# %%
from plotnine import *
from sklearn.manifold import TSNE
genesets = pd.read_csv("C:\\Users\\nisha\\Downloads\\IFN.txt",names=['member'])
genesets['name']='blank'
X=TSNE(n_components=2).fit_transform(df1.T)
dfn=pd.DataFrame(X).rename(columns={0:'x',1:'y'})
# print(dfn)
# (ggplot(dfn,aes(x='x',y='y'))
#  +geom_point(alpha=0.2))
# signature_df = gsva(df1, genesets)
# Y=TSNE(n_components=2).fit_transform(signature_df.T)
# pf=pd.DataFrame(Y).rename(columns={0:'x',1:'y'})
# (ggplot(pf,aes(x='x',y='y'))+geom_point(alpha=0.2))
# print(df1.head())
# print(genesets)
